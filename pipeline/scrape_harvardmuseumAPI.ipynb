# %%
import requests
import os
import csv
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Load API key
API_KEY = os.getenv("API_KEY")

# Base URL of the Harvard Art Museums API
BASE_URL = 'https://api.harvardartmuseums.org'

# Endpoint for searching objects
SEARCH_ENDPOINT = '/object'

# Parameters for your search
params = {
    'apikey': API_KEY,
    'classification': 'Paintings',  # Filter by classification (Paintings)
    'keyword': 'Chinese ink',       # Filter by keyword (Chinese ink)
    'size': 5000                     # Number of results to retrieve
}

def fetch_data(endpoint, params):
    try:
        response = requests.get(BASE_URL + endpoint, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.json()
    except requests.exceptions.RequestException as e:
        print('Error:', e)

def download_image(url, filename):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Save the image file
        with open(filename, 'wb') as f:
            f.write(response.content)
        print('Downloaded:', filename)
    except requests.exceptions.RequestException as e:
        print('Error downloading image:', e)

def main():
    # Fetch data from the API
    data = fetch_data(SEARCH_ENDPOINT, params)
    # Specify the folder to save images
    save_folder = 'images'

    if data: 
        # Specify the CSV filename
        csv_filename = 'artworks.csv'
        with open(csv_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=data['records'][1].keys())
            writer.writeheader()
            # Process the data
            for artwork in data['records']:
                # Check if the artwork has a primaryimageurl and it's not None
                if artwork.get('primaryimageurl') is not None:
                    writer.writerow(artwork)
                    # Print the title of the artwork
                    print('Title:', artwork['title'])
                    # Construct the download link for the image
                    download_link = artwork['primaryimageurl'] + '?height=500'  # Example: Resize image to height of 500px
                    print('Download link:', download_link)

                    # Extract filename from the URL
                    filename = str(artwork['id']) + '.jpg'

                    # Download the image file
                    download_image(download_link, filename)
                    print()  # Add a newline for readability
        

if __name__ == '__main__':
    main()
# Out:
# Title: Landscape with Fisherman in Three Scrolls
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV019848_dynmc?height=500
# Downloaded: 192073.jpg
#
# Title: Pair of Calligraphy Scrolls (2 of 2)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV004592_dynmc?height=500
# Downloaded: 190148.jpg
#
# Title: Landscape with Sailboat, lefthand scroll of a set of three
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV019854_dynmc?height=500
# Downloaded: 192069.jpg
#
# Title: Landscape with Waterfall, central scroll of a set of three
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV019859_dynmc?height=500
# Downloaded: 192461.jpg
#
# Title: Landscape with Fisherman, righthand scroll of a set of three
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV019848_dynmc?height=500
# Downloaded: 199782.jpg
#
# Title: Blossoming Plum under Sun and Moon (right scroll)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:767030?height=500
# Downloaded: 377682.jpg
#
# Title: Blossoming Plum under Sun and Moon (left scroll)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:767034?height=500
# Downloaded: 377683.jpg
#
# Title: Set of 3 scrolls: Wagtail on a Rock (ptg) and 2 One-line Calligraphies
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV019954_dynmc?height=500
# Downloaded: 191750.jpg
#
# Title: Pair of Paintings: Morning Glories (left) and Evening Glories (right)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV014761_dynmc?height=500
# Downloaded: 191692.jpg
#
# Title: Moon, Gourds, and Insects
# Download link: https://nrs.harvard.edu/urn-3:HUAM:766429?height=500
# Downloaded: 199471.jpg
#
# Title: Morning Glories and Butterflies
# Download link: https://nrs.harvard.edu/urn-3:HUAM:766400?height=500
# Downloaded: 211939.jpg
#
# Title: Portrait of a Seated Civil Official
# Download link: https://nrs.harvard.edu/urn-3:HUAM:74313_dynmc?height=500
# Downloaded: 206500.jpg
#
# Title: Landscape
# Download link: https://nrs.harvard.edu/urn-3:HUAM:DDC111057_dynmc?height=500
# Downloaded: 336551.jpg
#
# Title: Blossoming Branch of an Old, Weathered Plum Tree
# Download link: https://nrs.harvard.edu/urn-3:HUAM:71986_dynmc?height=500
# Downloaded: 169024.jpg
#
# Title: A Pavilion Secluded in a Bamboo Grove
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73743_dynmc?height=500
# Downloaded: 172725.jpg
#
# Title: Enjoying the Mountain Scenery
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73744_dynmc?height=500
# Downloaded: 173035.jpg
#
# Title: Seated Chijang Posal (Chinese, Dizang Pusa; Sanskrit, Bodhisattva Ksitigarbha) Flanked by Monk Tomyŏng (Chinese, Daoming) and Demon King Mutŏk Kuiwang (Chinese, Wudu Guiwang) and Surrounded by the Ten Kings of Hell and Their Retinues
# Download link: https://nrs.harvard.edu/urn-3:HUAM:772047?height=500
# Downloaded: 173617.jpg
#
# Title: Landscape with a Figure Crossing a Bridge to Reach a Village Nestled in a Mountain Valley
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73741_dynmc?height=500
# Downloaded: 174248.jpg
#
# Title: Alms-Bowl Pond (Pal-yŏn) in the Diamond Mountains [Kŭm-kang-san], originally in an album depicting the "Complete Views of the Diamond Mountains" [Kŭm-kang chŏn-to]
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73740_dynmc?height=500
# Downloaded: 174439.jpg
#
# Title: Verdant Cliffs at Ku-tam [Tortoise Lake], Tan-yang, probably originally from an album of eight leaves depicting "Eight Views of Tan-yang" [Tan-yang p'al-kyŏng]
# Download link: https://nrs.harvard.edu/urn-3:HUAM:70807_dynmc?height=500
# Downloaded: 174781.jpg
#
# Title: Orchid and Rock
# Download link: https://nrs.harvard.edu/urn-3:HUAM:71981_dynmc?height=500
# Downloaded: 174842.jpg
#
# Title: Landscape After Wang Meng's "Immortal Abode in the Pine Covered Mountains"
# Download link: https://nrs.harvard.edu/urn-3:HUAM:70804_dynmc?height=500
# Downloaded: 174968.jpg
#
# Title: Landscape After Dong Yuan
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV013999_dynmc?height=500
# Downloaded: 175142.jpg
#
# Title: Early Spring Blossoms on an Old, Gnarled Plum Tree
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73742_dynmc?height=500
# Downloaded: 175401.jpg
#
# Title: Kingfisher Over a Lotus Pond (Putang cuiyu tu)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:78690_dynmc?height=500
# Downloaded: 176958.jpg
#
# Title: Mountain Landscape with Waterfall, Village, and Distant Pagoda
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73726_dynmc?height=500
# Downloaded: 182463.jpg
#
# Title: Mountain Landscape with Lake, Two Villages, and Distant Inn with Flagpole
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73727_dynmc?height=500
# Downloaded: 182531.jpg
#
# Title: Old Weathered Plum Tree with Spring Blossoms, in the Manner of the Chinese Painter Wu Zhen (1280-1354)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:71985_dynmc?height=500
# Downloaded: 188152.jpg
#
# Title: Blossoming Plum
# Download link: https://nrs.harvard.edu/urn-3:HUAM:71984_dynmc?height=500
# Downloaded: 188168.jpg
#
# Title: A Gathering of Scholars in a Garden ('Touhu tu')
# Download link: https://nrs.harvard.edu/urn-3:HUAM:769931?height=500
# Downloaded: 189098.jpg
#
# Title: Plum in Snow
#
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73819_dynmc?height=500
# Downloaded: 189741.jpg
#
# Title: Chrysanthemum with Frost
#
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73820_dynmc?height=500
# Downloaded: 189742.jpg
#
# Title: Pumpkins and Wild Grapes with Insects
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV014010_dynmc?height=500
# Downloaded: 190125.jpg
#
# Title: Bamboo and Rock
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV014158_dynmc?height=500
# Downloaded: 190166.jpg
#
# Title: Set of Three Paintings of Rocks
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS43116_dynmc?height=500
# Downloaded: 191776.jpg
#
# Title: Chrysanthemum and Grasses
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11139?height=500
# Downloaded: 193802.jpg
#
# Title: A Courtier Viewing Autumn Maples (Momijigari)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11626_dynmc?height=500
# Downloaded: 193813.jpg
#
# Title: Three Geese in Moonlight
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11141_dynmc?height=500
# Downloaded: 193900.jpg
#
# Title: Fierce Deity Riding Horse
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV006471_dynmc?height=500
# Downloaded: 197759.jpg
#
# Title: Mandala with Tara in Center
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV006469_dynmc?height=500
# Downloaded: 197760.jpg
#
# Title: Garden Rock and Flowers (after a painting by Ma Shouzhen)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:758599?height=500
# Downloaded: 198020.jpg
#
# Title: Samurai and Lady
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS18274_dynmc?height=500
# Downloaded: 199419.jpg
#
# Title: Frozen Clouds About to Snow
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS16722_dynmc?height=500
# Downloaded: 199459.jpg
#
# Title: Scholar Seated on a Bench Before a Painted Screen in a Garden
# Download link: https://nrs.harvard.edu/urn-3:HUAM:LEG260972?height=500
# Downloaded: 199685.jpg
#
# Title: Landscape
# Download link: https://nrs.harvard.edu/urn-3:huam:DDC112684_dynmc?height=500
# Downloaded: 199789.jpg
#
# Title: Standing Courtesan
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS18272_dynmc?height=500
# Downloaded: 199813.jpg
#
# Title: Autumn Landscape
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11383_dynmc?height=500
# Downloaded: 199864.jpg
#
# Title: Illustration from the Tale of Sumiyoshi (Sumiyoshi monogatari)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:767445?height=500
# Downloaded: 199912.jpg
#
# Title: Standing Beauty in a Dance Pose
# Download link: https://nrs.harvard.edu/urn-3:HUAM:789406?height=500
# Downloaded: 199995.jpg
#
# Title: Catching Insects
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11384?height=500
# Downloaded: 200053.jpg
#
# Title: Scholar on a Bridge in a Landscape
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS41215_dynmc?height=500
# Downloaded: 200094.jpg
#
# Title: "One-Finger Zen" of Monk Chü-chih
# Download link: https://nrs.harvard.edu/urn-3:HUAM:763877?height=500
# Downloaded: 200165.jpg
#
# Title: Catching the Ferry
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11691?height=500
# Downloaded: 200301.jpg
#
# Title: Bamboo in Wind and Rain
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS12739?height=500
# Downloaded: 200405.jpg
#
# Title: Daizuigu Bosatsu (Mahapratisara)
#
# Download link: https://nrs.harvard.edu/urn-3:HUAM:757741?height=500
# Downloaded: 200412.jpg
#
# Title: Blue and Green Landscape
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS16285_dynmc?height=500
# Downloaded: 200524.jpg
#
# Title: Copy of "Scholar on a Bridge in a Landscape" (1994.111.1) attributed to Bunsei
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS41216_dynmc?height=500
# Downloaded: 200534.jpg
#
# Title: Yang Guifei Mounting a Horse
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS11692_dynmc?height=500
# Downloaded: 200703.jpg
#
# Title: Bamboo in Autumn
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS12736_dynmc?height=500
# Downloaded: 200744.jpg
#
# Title: Mountain Stream in Heavy Rain
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS40512_dynmc?height=500
# Downloaded: 200746.jpg
#
# Title: Two Scholars Under Bamboo Admiring a Waterfall
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS12853_dynmc?height=500
# Downloaded: 200820.jpg
#
# Title: Bamboo in Autumn
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS12736_dynmc?height=500
# Downloaded: 200961.jpg
#
# Title: Eight Views (Hakkei)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS19657_dynmc?height=500
# Downloaded: 201029.jpg
#
# Title: Yueyang Pavilion (after Shao Zhenxian)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:DDC100688_dynmc?height=500
# Downloaded: 201054.jpg
#
# Title: Moon and Grass Plumes
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS41621_dynmc?height=500
# Downloaded: 201163.jpg
#
# Title: Landscape of a Misty Mountain Scene
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV026876_dynmc?height=500
# Downloaded: 201166.jpg
#
# Title: Landscape after Yen Wen-kuei
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS15145_dynmc?height=500
# Downloaded: 201167.jpg
#
# Title: Peach Blossom Spring (after Shao Zhenxian)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:DDC100686_dynmc?height=500
# Downloaded: 201168.jpg
#
# Title: Bamboo and Plum
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS19927_dynmc?height=500
# Downloaded: 201182.jpg
#
# Title: Grasses and Insects: Dragonfly, Praying Mantis, Bumblebee
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS19659_dynmc?height=500
# Downloaded: 201197.jpg
#
# Title: Summer Mountains After Rain
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS41623_dynmc?height=500
# Downloaded: 201215.jpg
#
# Title: Herdboy on Buffalo
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS19661_dynmc?height=500
# Downloaded: 201306.jpg
#
# Title: Susuki Grass and Cricket
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS40190_dynmc?height=500
# Downloaded: 201308.jpg
#
# Title: Distant Peaks in Floating Mist (after a painting by Juran)
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS15782_dynmc?height=500
# Downloaded: 201412.jpg
#
# Title: Portrait of a Seated Korean Gentleman in a White Robe
# Download link: https://nrs.harvard.edu/urn-3:HUAM:73728_dynmc?height=500
# Downloaded: 201467.jpg
#
# Title: Fisherman in a Mist-Enshrouded Landscape
# Download link: https://nrs.harvard.edu/urn-3:HUAM:DDC106425_dynmc?height=500
# Downloaded: 201492.jpg
#
# Title: Portrait of Lu Zhi
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV015030_dynmc?height=500
# Downloaded: 201751.jpg
#
# Title: Two Orchids
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS12676?height=500
# Downloaded: 201793.jpg
#
# Title: Avalokitesvara (Kannon Bosatsu) from the Paradise of Amitâbha Buddha (Amida Nyorai); A painted copy of one detail from the Hōryū-ji Kondō murals
# Download link: https://nrs.harvard.edu/urn-3:HUAM:INV014903_dynmc?height=500
# Downloaded: 201815.jpg
#
# Title: Landscape with Willows
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS16804_dynmc?height=500
# Downloaded: 201896.jpg
#
# Title: Go Game in the Pine Pavilion
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS16721_dynmc?height=500
# Downloaded: 201899.jpg
#
# Title: Birds and Lotus
# Download link: https://nrs.harvard.edu/urn-3:HUAM:VRS16677_dynmc?height=500
# Downloaded: 201901.jpg
#
# Title: Portrait of Sugawara no Michizane (Kitano Tenjin)
# Download link: https://nrs.harvard.edu/urn-3:huam:LEG008924_dynmc?height=500
# Downloaded: 201966.jpg

# %%
data = fetch_data(SEARCH_ENDPOINT, params)
# for artwork in data['records'][:3]:
#     print(artwork.get('primaryimageurl'))
#     print(artwork['primaryimageurl'])
data['records'][1]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Bequest of the Hofer Collection of the Arts of Asia',
#  'accesslevel': 1,
#  'dateoflastpageview': '2024-03-20',
#  'classificationid': 26,
#  'division': 'Asian and Mediterranean Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 49,
#  'contact': 'am_asianmediterranean@harvard.edu',
#  'colorcount': 3,
#  'rank': 109628,
#  'id': 211205,
#  'state': None,
#  'verificationleveldescription': 'Unchecked. Object information has not been verified for completeness and has not been vetted',
#  'period': 'Edo period, 1615-1868',
#  'images': [{'date': '2005-05-06',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 54566,
#    'idsid': 18744696,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'INV005769',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV005769_dynmc',
#    'alttext': None,
#    'width': 1024,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18744696',
#    'height': 546},
#   {'date': '2005-05-06',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 110142,
#    'idsid': 18744695,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'INV005768',
#    'displayorder': 2,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV005768_dynmc',
#    'alttext': None,
#    'width': 180,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18744695',
#    'height': 1024}],
#  'worktypes': [{'worktypeid': '248', 'worktype': 'painting'},
#   {'worktypeid': '171', 'worktype': 'hanging scroll'}],
#  'imagecount': 2,
#  'totalpageviews': 60,
#  'accessionyear': 1985,
#  'standardreferencenumber': None,
#  'signed': 'Tzu-ang (with inscription)',
#  'classification': 'Paintings',
#  'relatedcount': 0,
#  'verificationlevel': 0,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV005769_dynmc',
#  'titlescount': 1,
#  'peoplecount': 1,
#  'style': None,
#  'lastupdate': '2024-04-08T04:58:12-0400',
#  'commentary': None,
#  'periodid': 248,
#  'technique': None,
#  'edition': None,
#  'description': None,
#  'medium': 'Hanging scroll; ink on silk',
#  'lendingpermissionlevel': 0,
#  'title': 'Copy of a Chinese Landscape',
#  'accessionmethod': 'Bequest',
#  'colors': [{'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.7751898734177215,
#    'css3': '#808080'},
#   {'color': '#96967d',
#    'spectrum': '#8e5ea7',
#    'hue': 'Green',
#    'percent': 0.18143459915611815,
#    'css3': '#808080'},
#   {'color': '#64644b',
#    'spectrum': '#59ba4a',
#    'hue': 'Green',
#    'percent': 0.04337552742616034,
#    'css3': '#696969'}],
#  'provenance': 'Philip Hofer (1898-1984), Cambridge, MA, purchased from the estate of Rhode Island Senator Theodore Francis Green, July 1968; bequest to Harvard Art Museum',
#  'groupcount': 0,
#  'dated': '17th-18th century',
#  'department': 'Department of Asian Art',
#  'dateend': 0,
#  'people': [{'role': 'Artist',
#    'birthplace': None,
#    'gender': 'unknown',
#    'displaydate': '1254 - 1322',
#    'prefix': 'Copy after',
#    'culture': 'Chinese',
#    'displayname': 'Copy after Zhao Mengfu 趙孟頫',
#    'alphasort': 'Zhao, Mengfu',
#    'name': 'Zhao Mengfu 趙孟頫',
#    'personid': 32053,
#    'deathplace': None,
#    'displayorder': 1}],
#  'url': 'https://www.harvardartmuseums.org/collections/object/211205',
#  'dateoffirstpageview': '2009-05-24',
#  'century': '17th-18th century',
#  'objectnumber': '1985.862',
#  'labeltext': None,
#  'datebegin': 0,
#  'culture': 'Chinese',
#  'exhibitioncount': 0,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 211205,
#  'techniqueid': None,
#  'dimensions': 'H. 28.6 x W. 53.3 cm (11 1/4 x 21 in.)',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/211205',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}]}
